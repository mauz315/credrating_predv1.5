# %% [markdown]
# # Explorar datos de emisor

# %% [markdown]
# Este archivo grafica las variables históricas para un emisor existente en la base de datos original.

# %% [markdown]
# ## 1. Cargando archivos y librerías necesarias

# %%
from data_handler import issuer_choice, data_handler
# %matplotlib inline
data_file = 'data_em_1212_0119.csv'

# %% [markdown]
# ## 2. Recuperar data con Ticker CIQ

# %% [markdown]
# Ingresar el nombre del emisor de la lista desplegable para obtener el ticker CIQ.

# %%
issuer_choice()
# Out:
# Dropdown(description='Emisor:', options=('361 Degrees International Limited', 'Abu Dhabi National Energy Compa…
# Button(description='Obtain CIQ', style=ButtonStyle())
# Output()

# %% [markdown]
# ## 3. Graficar las variables del emisor escogido

# %% [markdown]
# Copiar el Ticker CIQ debajo. Al corre la celda, se muestra un gráfico por cada variable trimestral y el promedio LTM

# %%
ticker = 'IQT297911881'
data_handler(data_file, ticker)
# Out:
# Utilidad Operacional del Trimestre / Activo Total
# Margen EBITDA del Trimestre
# Deuda Neta / EBITDA del Trimestre Anualizado
# Deuda de Corto Plazo / Deuda Total
# Deuda Bruta / Activo
# EBITDA del Trimestre Anualizado / Intereses
# EBITDA del Trimestre Anualizado / Deuda Corto Plazo
# Activo Corto Plazo / Pasivo Corto Plazo
# Crecimiento del EBITDA Últimos 12 Meses EBITDA
# Margen Neto del Trimestre
# Ingresos del Trimestre Anualizados / Total Activo
# Total Activo / Total Patrimonio
# Utilidad Neta del Trimestre Anualizada / Total Patrimonio
