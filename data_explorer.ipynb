# %% [markdown]
# # Explorar datos de emisor

# %% [markdown]
# Este archivo grafica las variables históricas para un emisor existente en la base de datos original.

# %% [markdown]
# ## 1. Cargando archivos y librerías necesarias

# %%
from data_handler import issuer_choice, data_handler
# %matplotlib inline
data_file = 'research_data_banks.csv'

# %% [markdown]
# ## 2. Recuperar data con Ticker CIQ

# %% [markdown]
# Ingresar el nombre del emisor de la lista desplegable para obtener el ticker CIQ. Al hacer click en "Obtener CIQ", se mostrarán las variables (y sus promedios LTM) contenidas en la base de datos del algoritmo para el emisor escogido.

# %%
issuer_choice(data_file)
# Out:
# Dropdown(description='Emisor:', index=13, options=('Banco Hipotecario S.A.', 'Banco Macro S.A.', 'Banco Patago…
# Button(description='Obtener CIQ', style=ButtonStyle())
# Output()
# ROAE / ROAA
# (Total Patrimonio + Interés Minoritario + Provisiones) / Cartera Bruta
# (Cartera Bruta + Caja & Eq. + Inversiones) / Pasivos con Costo
# Provisiones / Cartera Bruta
# Gasto en Provisiones / Cartera Bruta
# Ingreso Neto por Intereses / (Cartera Bruta + Caja & Eq. + Inversiones)
# Gasto no financiero / Ingreso Total
# Ingreso No Financiero / Ingreso Total
# ROAA
# Utilidad Neta / Ingreso Total
# Ingreso Total / Total Activo x 4
# ROAE
# (Caja & Eq. + Inversiones) / Total Activo
# Caretera Bruta / Depósitos Totales
# Depósitos Totales / Total Pasivo
