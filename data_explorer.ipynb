# %% [markdown]
# # Explorar datos de emisor

# %% [markdown]
# Este archivo grafica todas las variables para el emisor existente tal y como se encuentran en la base de datos original.

# %% [markdown]
# ## 1. Cargando archivos y librerías necesarias

# %%
from data_handler import issuer_choice, data_handler
data_file = 'data_em_1212_0119.csv'

# %% [markdown]
# ## 2. Recuperar data con Ticker CIQ

# %% [markdown]
# Ingresar el nombre del emisor de la lista desplegable para obtener el ticker CIQ

# %%
issuer_choice()
# Out:
# interactive(children=(Dropdown(description='Emisor', options=('361 Degrees International Limited', 'Abu Dhabi …

# %% [markdown]
# ## 3. Graficar las variables del emisor escogido

# %% [markdown]
# Se muestra un gráfico por cada variable trimestral y LTM

# %%
data_handler(data_file)
# Out:
# Utilidad Operacional del Trimestre / Activo Total y LTM:
# Margen EBITDA del Trimestre y LTM:
# Deuda Neta / EBITDA del Trimestre Anualizado y LTM:
# Deuda de Corto Plazo / Deuda Total y LTM:
# Deuda Bruta / Activo y LTM:
# EBITDA del Trimestre Anualizado / Intereses y LTM:
# EBITDA del Trimestre Anualizado / Deuda Corto Plazo y LTM:
# Activo Corto Plazo / Pasivo Corto Plazo y LTM:
# Crecimiento del EBITDA Últimos 12 Meses EBITDA y LTM:
# Margen Neto del Trimestre y LTM:
# Ingresos del Trimestre Anualizados / Total Activo y LTM:
# Total Activo / Total Patrimonio y LTM:
# Utilidad Neta del Trimestre Anualizada / Total Patrimonio y LTM:
